# %% [markdown]
# # Final Project: Data Science Analysis
#
# This notebook contains the final project for the Data Science Workshop.

# %%
# Import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

print("Libraries imported successfully!")

# %%
# Load sample data
data = {
    'x': np.random.rand(100),
    'y': np.random.rand(100)
}
df = pd.DataFrame(data)
print(df.head())

# %%
# Create a simple plot
plt.scatter(df['x'], df['y'])
plt.title('Random Scatter Plot')
plt.xlabel('X values')
plt.ylabel('Y values')
plt.show()
